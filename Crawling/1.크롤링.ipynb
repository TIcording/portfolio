<a href="https://basicenglishspeaking.com/tv-program/">TV program</a>, <a href="https://basicenglishspeaking.com/architecture-building/">Architect/ Building</a>, <a href="https://basicenglishspeaking.com/electronic-media/">Electronic Media</a>, <a href="https://basicenglishspeaking.com/job-career/">Job/ Career</a>, <a href="https://basicenglishspeaking.com/competition-contest/">Competition/ contest</a>, <a href="https://basicenglishspeaking.com/a-garden/">A garden</a>, <a href="https://basicenglishspeaking.com/hometown/">Hometown</a>, <a href="https://basicenglishspeaking.com/clothing/">Clothing</a>, <a href="https://basicenglishspeaking.com/an-advertisement/">Advertisement</a>, <a href="https://basicenglishspeaking.com/a-project/">A project</a>, <a href="https://basicenglishspeaking.com/a-wedding/">A wedding</a>, <a href= ...

# %%
for link in links:
  print(link.text)
# Out:
# Family
# Restaurant
# Books
# Travel
# Website
# Accident
# Childhood memory
# Favorite rooms
# Presents
# Historical place
# Newspaper/ Magazine
# A memorable event
# A favorite subject
# A museum
# A favorite movie
# A foreign country
# Parties
# A teacher
# A friend
# A hotel
# A letter
# Hobbies
# Music
# Shopping
# Holiday
# Animals
# A practical skill
# Sport
# A School
# Festival
# Food
# Household appliance
# A music band
# Weather
# Neighbor
# Natural scenery
# Outdoor activities
# Law
# Pollution
# Traffic jam
# TV program
# Architect/ Building
# Electronic Media
# Job/ Career
# Competition/ contest
# A garden
# Hometown
# Clothing
# Advertisement
# A project
# A wedding
# A Coffee shop
# Culture
# Transport
# Politician
# Communication
# Business
# Computer
# Exercise
# Goal/ ambition
# Art
# Fashion
# Jewelry
# Cosmetic
# Indoor Game
# Phone conversation
# Learning A Second language
# A Creative Person
# A celebrity
# A Health Problem
# Technological advancements
# A Landmark
# Handcraft Items
# Plastic Surgery
# Success

# %%
subject = []

for link in links:
  subject.append(link.text)

# %%
len(subject)
# Out:
# 75

# %%
print('총',len(subject),'개의 주제를 찾음')

for i in range(len(subject)):
  print('{0:2d},{1:s}'.format(i+1, subject[i]))
# Out:
# 총 75 개의 주제를 찾음
#  1,Family
#  2,Restaurant
#  3,Books
#  4,Travel
#  5,Website
#  6,Accident
#  7,Childhood memory
#  8,Favorite rooms
#  9,Presents
# 10,Historical place
# 11,Newspaper/ Magazine
# 12,A memorable event
# 13,A favorite subject
# 14,A museum
# 15,A favorite movie
# 16,A foreign country
# 17,Parties
# 18,A teacher
# 19,A friend
# 20,A hotel
# 21,A letter
# 22,Hobbies
# 23,Music
# 24,Shopping
# 25,Holiday
# 26,Animals
# 27,A practical skill
# 28,Sport
# 29,A School
# 30,Festival
# 31,Food
# 32,Household appliance
# 33,A music band
# 34,Weather
# 35,Neighbor
# 36,Natural scenery
# 37,Outdoor activities
# 38,Law
# 39,Pollution
# 40,Traffic jam
# 41,TV program
# 42,Architect/ Building
# 43,Electronic Media
# 44,Job/ Career
# 45,Competition/ contest
# 46,A garden
# 47,Hometown
# 48,Clothing
# 49,Advertisement
# 50,A project
# 51,A wedding
# 52,A Coffee shop
# 53,Culture
# 54,Transport
# 55,Politician
# 56,Communication
# 57,Business
# 58,Computer
# 59,Exercise
# 60,Goal/ ambition
# 61,Art
# 62,Fashion
# 63,Jewelry
# 64,Cosmetic
# 65,Indoor Game
# 66,Phone conversation
# 67,Learning A Second language
# 68,A Creative Person
# 69,A celebrity
# 70,A Health Problem
# 71,Technological advancements
# 72,A Landmark
# 73,Handcraft Items
# 74,Plastic Surgery
# 75,Success

# %% [markdown]
# # 2.다음 뉴수기사

# %%
#https://v.daum.net/v/20230601073036722
#https://v.daum.net/v/20230601090258959

def duam_news_title(new_id):
  url = 'https://v.daum.net/v/{}'.format(new_id)
  request =requests.get(url)
  soup = BeautifulSoup(request.text) 
  title = soup.find('h3',{'class':'tit_view'})
  if title:
    return title.text.strip()
  else:
    return '제목없음'

# %%
duam_news_title(20230601073036722)
# Out:
# '[뉴스1 PICK]6년 만에 캡사이신 분사기 꺼내든 경찰'

# %%
duam_news_title(20230601090258959)
# Out:
# '“푸바오 영상 보며 힐링해요”…건강에 ‘이런’ 효과 있다'

# %% [markdown]
# # 3. 벅스뮤직차트
# * https://music.bugs.co.kr/chart

# %%
request = requests.get('https://music.bugs.co.kr/chart')
soup = BeautifulSoup(request.text)

# %%
titles = soup.findAll('p',{'class':'title'})
# print(titles)
artists =soup.findAll('p',{'class':'artist'})
# print(artists)

# %%
for i in range(len(titles)):
  title = titles[i].text.strip()
  artist = artists[i].text.strip().split('\n')[0]
  print('{0:3d}위 {1}-{2}'.format(i+1,artist,title))
# Out:
#   1위 (여자)아이들-퀸카 (Queencard)
#   2위 aespa-Spicy
#   3위 IVE (아이브)-I AM
#   4위 LE SSERAFIM (르세라핌)-UNFORGIVEN (feat. Nile Rodgers)
#   5위 IVE (아이브)-Kitsch
#   6위 LE SSERAFIM (르세라핌)-이브, 프시케 그리고 푸른 수염의 아내
#   7위 세븐틴(SEVENTEEN)-손오공
#   8위 FIFTY FIFTY-Cupid
#   9위 aespa-Thirsty
#  10위 NewJeans-Hype Boy
#  11위 NewJeans-Ditto
#  12위 이채연-KNOCK
#  13위 지수(JISOO)-꽃
#  14위 (여자)아이들-Allergy
#  15위 NewJeans-OMG
#  16위 Charlie Puth(찰리 푸스)-Dangerously
#  17위 STAYC(스테이씨)-Teddy Bear
#  18위 IVE (아이브)-After LIKE
#  19위 NewJeans-Attention
#  20위 부석순(SEVENTEEN)-파이팅 해야지 (Feat. 이영지)
#  21위 박재정-헤어지자 말해요
#  22위 윤하(Younha/ユンナ)-사건의 지평선
#  23위 멜로망스(MeloMance)-찬란한 하루
#  24위 H1-KEY (하이키)-건물 사이에 피어난 장미 (Rose Blossom)
#  25위 Charlie Puth(찰리 푸스)-I Don’t Think That I Like Her
#  26위 IVE (아이브)-LOVE DIVE
#  27위 LE SSERAFIM (르세라핌)-ANTIFRAGILE
#  28위 NMIXX-Love Me Like This
#  29위 aespa-Salty & Sweet
#  30위 던 (DAWN)-빛이 나는 너에게
#  31위 DK(디셈버)-심(心)
#  32위 Charlie Puth(찰리 푸스)-That’s Not How This Works (feat. Dan + Shay)
#  33위 비투비-나의 바람 (Wind And Wish)
#  34위 FIFTY FIFTY-Cupid (Twin Ver.)
#  35위 DAY6 (데이식스)-한 페이지가 될 수 있게
#  36위 태연 (TAEYEON)-INVU
#  37위 Christopher(크리스토퍼)-When I Get Old
#  38위 10CM-부동의 첫사랑
#  39위 이무진-잠깐 시간 될까
#  40위 10CM-그라데이션
#  41위 윤하(Younha/ユンナ)-오르트구름
#  42위 멜로망스(MeloMance)-사랑인가 봐
#  43위 폴킴(Paul Kim)-한강에서 (Feat. BIG Naughty)
#  44위 BLACKPINK-Shut Down
#  45위 (여자)아이들-TOMBOY
#  46위 지올팍(Zior Park)-CHRISTIAN
#  47위 임재현-Heaven(2023)
#  48위 IVE (아이브)-ELEVEN
#  49위 허각-물론
#  50위 LE SSERAFIM (르세라핌)-FEARLESS
#  51위 Charlie Puth(찰리 푸스)-That's Hilarious
#  52위 NCT DREAM-Candy
#  53위 박재범-Candy (Feat. Zion.T)
#  54위 BLACKPINK-Pink Venom
#  55위 성시경-너의 모든 순간
#  56위 볼빨간사춘기-FRIEND THE END
#  57위 The Kid LAROI-STAY
#  58위 경서예지-다정히 내 이름을 부르면
#  59위 BIG Naughty (서동현)-정이라고 하자 (Feat. 10CM)
#  60위 (여자)아이들-Nxde
#  61위 STAYC(스테이씨)-Poppy (Korean Ver.)
#  62위 잔나비-주저하는 연인들을 위해
#  63위 aespa-도깨비불 (Illusion)
#  64위 김민석 (멜로망스)-취중고백
#  65위 폴킴(Paul Kim)-모든 날, 모든 순간 (Every day, Every Moment)
#  66위 NewJeans-Cookie
#  67위 테이(Tei)-Monologue
#  68위 Crush-Rush Hour (Feat. j-hope of BTS)
#  69위 경서-나의 X에게
#  70위 아이유(IU)-strawberry moon
#  71위 Justin Bieber(저스틴 비버)-Off My Face
#  72위 NCT 도재정-Perfume
#  73위 태양-VIBE (feat. Jimin of BTS)
#  74위 방탄소년단-Dynamite
#  75위 Sam Smith(샘 스미스)-Unholy
#  76위 지아(Zia)-사랑..그게 뭔데
#  77위 카라(Kara)-WHEN I MOVE
#  78위 #안녕-해요 (2022)
#  79위 지코 (ZICO)-새삥 (Prod. ZICO) (Feat. 호미들)
#  80위 우디(Woody)-Say I Love You
#  81위 주주 시크릿-밤이 무서워요 (Lonely Night)
#  82위 WSG워너비 (가야G)-그때 그 순간 그대로 (그그그)
#  83위 태양-나의 마음에 (Seed)
#  84위 Red Velvet (레드벨벳)-Feel My Rhythm
#  85위 10CM-딱 10CM만
#  86위 임영웅-사랑은 늘 도망가
#  87위 aespa-Welcome To MY World (Feat. nævis)
#  88위 주호-내가 아니라도
#  89위 이영지-NOT SORRY (Feat. pH-1) (Prod. by Slom)
#  90위 BE'O (비오)-LOVE me
#  91위 aespa-I'm Unhappy
#  92위 V.O.S.-안녕이라고 말하지마
#  93위 우디(Woody)-Nostalgia
#  94위 아이유(IU)-드라마
#  95위 Charlie Puth(찰리 푸스)-Left and Right (Feat. Jung Kook of BTS)
#  96위 BIGBANG (빅뱅)-봄여름가을겨울 (Still Life)
#  97위 세븐틴(SEVENTEEN)-F*ck My Life
#  98위 먼데이 키즈(Monday Kiz)-이 세상 끝까지
#  99위 볼빨간사춘기-Love story
# 100위 경서-첫 키스에 내 심장은 120BPM

# %%
for i,(t,a) in enumerate(zip(titles,artists)):
    title_text = t.text.strip()
    artist_text = a.text.strip().split('\n')[0]
    print('{0:3d}위 {1}-{2}'.format(i+1, artist_text, title_text))
# Out:
#   1위 (여자)아이들-퀸카 (Queencard)
#   2위 aespa-Spicy
#   3위 IVE (아이브)-I AM
#   4위 LE SSERAFIM (르세라핌)-UNFORGIVEN (feat. Nile Rodgers)
#   5위 IVE (아이브)-Kitsch
#   6위 LE SSERAFIM (르세라핌)-이브, 프시케 그리고 푸른 수염의 아내
#   7위 세븐틴(SEVENTEEN)-손오공
#   8위 FIFTY FIFTY-Cupid
#   9위 aespa-Thirsty
#  10위 NewJeans-Hype Boy
#  11위 NewJeans-Ditto
#  12위 이채연-KNOCK
#  13위 지수(JISOO)-꽃
#  14위 (여자)아이들-Allergy
#  15위 NewJeans-OMG
#  16위 Charlie Puth(찰리 푸스)-Dangerously
#  17위 STAYC(스테이씨)-Teddy Bear
#  18위 IVE (아이브)-After LIKE
#  19위 NewJeans-Attention
#  20위 부석순(SEVENTEEN)-파이팅 해야지 (Feat. 이영지)
#  21위 박재정-헤어지자 말해요
#  22위 윤하(Younha/ユンナ)-사건의 지평선
#  23위 멜로망스(MeloMance)-찬란한 하루
#  24위 H1-KEY (하이키)-건물 사이에 피어난 장미 (Rose Blossom)
#  25위 Charlie Puth(찰리 푸스)-I Don’t Think That I Like Her
#  26위 IVE (아이브)-LOVE DIVE
#  27위 LE SSERAFIM (르세라핌)-ANTIFRAGILE
#  28위 NMIXX-Love Me Like This
#  29위 aespa-Salty & Sweet
#  30위 던 (DAWN)-빛이 나는 너에게
#  31위 DK(디셈버)-심(心)
#  32위 Charlie Puth(찰리 푸스)-That’s Not How This Works (feat. Dan + Shay)
#  33위 비투비-나의 바람 (Wind And Wish)
#  34위 FIFTY FIFTY-Cupid (Twin Ver.)
#  35위 DAY6 (데이식스)-한 페이지가 될 수 있게
#  36위 태연 (TAEYEON)-INVU
#  37위 Christopher(크리스토퍼)-When I Get Old
#  38위 10CM-부동의 첫사랑
#  39위 이무진-잠깐 시간 될까
#  40위 10CM-그라데이션
#  41위 윤하(Younha/ユンナ)-오르트구름
#  42위 멜로망스(MeloMance)-사랑인가 봐
#  43위 폴킴(Paul Kim)-한강에서 (Feat. BIG Naughty)
#  44위 BLACKPINK-Shut Down
#  45위 (여자)아이들-TOMBOY
#  46위 지올팍(Zior Park)-CHRISTIAN
#  47위 임재현-Heaven(2023)
#  48위 IVE (아이브)-ELEVEN
#  49위 허각-물론
#  50위 LE SSERAFIM (르세라핌)-FEARLESS
#  51위 Charlie Puth(찰리 푸스)-That's Hilarious
#  52위 NCT DREAM-Candy
#  53위 박재범-Candy (Feat. Zion.T)
#  54위 BLACKPINK-Pink Venom
#  55위 성시경-너의 모든 순간
#  56위 볼빨간사춘기-FRIEND THE END
#  57위 The Kid LAROI-STAY
#  58위 경서예지-다정히 내 이름을 부르면
#  59위 BIG Naughty (서동현)-정이라고 하자 (Feat. 10CM)
#  60위 (여자)아이들-Nxde
#  61위 STAYC(스테이씨)-Poppy (Korean Ver.)
#  62위 잔나비-주저하는 연인들을 위해
#  63위 aespa-도깨비불 (Illusion)
#  64위 김민석 (멜로망스)-취중고백
#  65위 폴킴(Paul Kim)-모든 날, 모든 순간 (Every day, Every Moment)
#  66위 NewJeans-Cookie
#  67위 테이(Tei)-Monologue
#  68위 Crush-Rush Hour (Feat. j-hope of BTS)
#  69위 경서-나의 X에게
#  70위 아이유(IU)-strawberry moon
#  71위 Justin Bieber(저스틴 비버)-Off My Face
#  72위 NCT 도재정-Perfume
#  73위 태양-VIBE (feat. Jimin of BTS)
#  74위 방탄소년단-Dynamite
#  75위 Sam Smith(샘 스미스)-Unholy
#  76위 지아(Zia)-사랑..그게 뭔데
#  77위 카라(Kara)-WHEN I MOVE
#  78위 #안녕-해요 (2022)
#  79위 지코 (ZICO)-새삥 (Prod. ZICO) (Feat. 호미들)
#  80위 우디(Woody)-Say I Love You
#  81위 주주 시크릿-밤이 무서워요 (Lonely Night)
#  82위 WSG워너비 (가야G)-그때 그 순간 그대로 (그그그)
#  83위 태양-나의 마음에 (Seed)
#  84위 Red Velvet (레드벨벳)-Feel My Rhythm
#  85위 10CM-딱 10CM만
#  86위 임영웅-사랑은 늘 도망가
#  87위 aespa-Welcome To MY World (Feat. nævis)
#  88위 주호-내가 아니라도
#  89위 이영지-NOT SORRY (Feat. pH-1) (Prod. by Slom)
#  90위 BE'O (비오)-LOVE me
#  91위 aespa-I'm Unhappy
#  92위 V.O.S.-안녕이라고 말하지마
#  93위 우디(Woody)-Nostalgia
#  94위 아이유(IU)-드라마
#  95위 Charlie Puth(찰리 푸스)-Left and Right (Feat. Jung Kook of BTS)
#  96위 BIGBANG (빅뱅)-봄여름가을겨울 (Still Life)
#  97위 세븐틴(SEVENTEEN)-F*ck My Life
#  98위 먼데이 키즈(Monday Kiz)-이 세상 끝까지
#  99위 볼빨간사춘기-Love story
# 100위 경서-첫 키스에 내 심장은 120BPM

# %% [markdown]
# # 4.멜론차트
# * https://www.melon.com/chart/index.htm
# * robots.txt : 웹 사이트에 크롤러같은 로봇들의 접글은 제어하기 위한 규약.
# 권고안이라 꼭 지킬의무는 없음

# %%
request = requests.get('https://www.melon.com/chart/index.htm')
print(request)
#406 -> 접속안됨
#헤더가 없는 접근은 제한됨 -> 만들어서 보내자
# Out:
# <Response [406]>

# %%
# User-Agent:
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36

header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}

request = requests.get('https://www.melon.com/chart/index.htm',headers=header)
print(request)
# 접속가능
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(request.text)

# %%
titles = soup.findAll('div',{'class':'rank01'})
# print(titles)
artists =soup.findAll('span',{'class':'checkEllipsis'})
# print(artists)

# %%
for i,(t,a) in enumerate(zip(titles,artists)):
    title_text = t.text.strip()
    artist_text = a.text.strip().split('\n')[0]
    print('{0:3d}위 {1}-{2}'.format(i+1, artist_text, title_text))
# Out:
#   1위 (여자)아이들-퀸카 (Queencard)
#   2위 aespa-Spicy
#   3위 IVE (아이브)-I AM
#   4위 LE SSERAFIM (르세라핌)-UNFORGIVEN (feat. Nile Rodgers)
#   5위 IVE (아이브)-Kitsch
#   6위 세븐틴 (SEVENTEEN)-손오공
#   7위 지수 (JISOO)-꽃
#   8위 NewJeans-Hype boy
#   9위 임영웅-사랑은 늘 도망가
#  10위 (여자)아이들-Allergy
#  11위 NewJeans-Ditto
#  12위 허각-물론
#  13위 FIFTY FIFTY-Cupid
#  14위 임영웅-우리들의 블루스
dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)
#  82위 10CM-그라데이션
#  83위 j-hope, J. Cole-on the street (with J. Cole)
#  84위 경서-첫 키스에 내 심장은 120BPM
#  85위 Charlie Puth-That’s Not How This Works (feat. Dan + Shay)
#  86위 BLACKPINK-Shut Down
#  87위 우디 (Woody)-Nostalgia
#  88위 IVE (아이브)-ELEVEN
#  89위 우디 (Woody)-Say I Love You
#  90위 BIG Naughty (서동현)-정이라고 하자 (Feat. 10CM)
#  91위 DK(디셈버)-발걸음
#  92위 LE SSERAFIM (르세라핌)-FEARLESS
#  93위 경서예지, 전건호-다정히 내 이름을 부르면
#  94위 주호-내가 아니라도
#  95위 김호중, 송가인-당신을 만나
#  96위 BLACKPINK-Pink Venom
#  97위 지코 (ZICO)-새삥 (Prod. ZICO) (Feat. 호미들)
#  98위 윤하 (YOUNHA)-오르트구름
#  99위 WSG워너비 (가야G)-그때 그 순간 그대로 (그그그)
# 100위 태양-VIBE (feat. Jimin of BTS)

# %% [markdown]
# # 5. 네이버 금융
# * https://finance.naver.com/

# %%
#https://finance.naver.com/item/main.naver?code=005930

site ='https://finance.naver.com/item/main.naver?code=005930'

request=requests.get(site)
print(request)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(request.text)

# %%
div_today = soup.find('div',{'class':'today'})
print(div_today)
# Out:
# <div class="today">
# <p class="no_today">
# <em class="no_down">
# <span class="blind">70,700</span>
# <span class="no7">7</span><span class="no0">0</span><span class="shim">,</span><span class="no7">7</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# </p>
# <p class="no_exday">
# <span class="sptxt sp_txt1">전일대비</span>
# <em class="no_down">
# <span class="ico down">하락</span>
# <span class="blind">700</span>
# <span class="no7">7</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# <span class="bar">l</span>
# <em class="no_down">
# <span class="ico minus">-</span>
# <span class="blind">0.98</span>
# <span class="no0">0</span><span class="jum">.</span><span class="no9">9</span><span class="no8">8</span>
# <span class="per">%</span>
# </em>
# </p>
# </div>

# %%
em =div_today.find('em')
print(em)
# Out:
# <em class="no_down">
# <span class="blind">70,700</span>
# <span class="no7">7</span><span class="no0">0</span><span class="shim">,</span><span class="no7">7</span><span class="no0">0</span><span class="no0">0</span>
# </em>

# %%
price = em.find('span',{'class':'blind'}).text
print(price)
# Out:
# 70,700

# %%
div_company =  soup.find('div',{'class':'wrap_company'})
print(div_company)
# Out:
# <div class="wrap_company">
# <h2><a href="#" onclick="clickcr(this, 'sop.title', '', '', event);window.location.reload();">삼성전자</a></h2>
# <div class="description">
# <span class="code">005930</span>
# <img alt="코스피" class="kospi" height="16" src="https://ssl.pstatic.net/imgstock/item_renewal/btn_kospi.gif" width="33"/>
# <span class="blind">날짜</span>
# <span id="time">
# <em class="date">2023.06.01  11:18 <span>기준(장중)</span></em>
# </span>
# <em class="realtime">
# <span class="blind">실시간</span>
# </em>
# <em class="summary">
# <a href="#" onclick="togglePannel('summary_lyr'); return false;"></a>
# <span class="blind">기업개요</span>
# <div class="summary_lyr" id="summary_lyr" style="display:none;top:22px;left:0">
# <iframe frameborder="0" height="" id="summary_ifr" name="summary_ifr" scrolling="no" src="" style="position:absolute;left:0;top:-2;z-index:20" width="410"></iframe>
# <div class="summary_info" id="summary_info">
# <h4>기업개요</h4>
# <p>한국 및 DX부문 해외 9개 지역총괄과 DS부문 해외 5개 지역총괄, SDC, Harman 등 232개의 종속기업으로 구성된 글로벌 전자기업임.</p>
# <p>세트사업은 TV를 비롯 모니터, 냉장고, 세탁기, 에어컨, 스마트폰, 네트워크시스템, 컴퓨터 등을 생산하는 DX부문이 있음.</p>
# <p>부품 사업에는 DRAM, NAND Flash, 모바일AP 등의 제품을 생산하고 있는 DS 부문과 중소형OLED 등의 디스플레이 패널을 생산하고 있는 SDC가 있음.</p>
# <div class="txt_notice">출처 : 에프앤가이드</div>
# <div class="btn_area_top">
# <a href="#" onclick="hidePannel('summary_lyr'); return false;"><img alt="닫기" height="11" src="https://ssl.pstatic.net/static/nfinance/img/btn_close.gif" width="11"/></a>
# </div>
# <div class="bg_btm"></div>
# </div>
# <span class="bg_lt"></span>
# <span class="bg_rt"></span>
# <div class="bu_arrow"></div>
# </div>
# </em>
# </div>
# </div>

# %%
title = div_company.find('h2').text
print(title)
code = div_company.find('span').text
print(code)
# Out:
# 삼성전자
# 005930

# %%
div_description = div_company.find('div',{'class':'description'})
# print(div_description)
#이런형식으로도 찾기가능(첫번째 것만 가져옴)
code2 = div_description.span.text
print(code2)
# Out:
# 005930

# %%
table_no_info = soup.find('table',{'class':'no_info'})
tds =table_no_info.findAll('td')

# %%
volume = tds[2].find('span',{'class':'blind'}).text
print(volume)
# Out:
# 6,960,517

# %%
dic = {'price':price,'name':title,'code':code,'volume':volume}
dic
# Out:
# {'price': '70,700', 'name': '삼성전자', 'code': '005930', 'volume': '6,960,517'}

# %%
def naver_finance(code):
    site = f'https://finance.naver.com/item/main.naver?code={code}'
    request = requests.get(site)
    soup = BeautifulSoup(request.text)
    div_today = soup.find('div', {'class':'today'})
    em = div_today.find('em')
    price = em.find('span', {'class':'blind'}).text # 가격
    wrap_company = soup.find('div', {'class':'wrap_company'})
    name = wrap_company.a.text  # 회사명
    div_description = wrap_company.find('div', {'class':'description'})
    code = div_description.span.text # 코드
    table_no_info = soup.find('table', {'class':'no_info'})
    tds = table_no_info.find_all('td')
    volume = tds[2].find('span', {'class':'blind'}).text # 거래량
    dic = {'price':price, 'name':name, 'code':code, 'volume':volume}
    return dic

# %%
naver_finance('000660')
# Out:
# {'price': '109,500', 'name': 'SK하이닉스', 'code': '000660', 'volume': '3,953,174'}

# %%
codes= ['005930','000660','373220','005070','247540']

# %%
data =[]

for code in codes:
  dic = naver_finance(code)
  data.append(dic)

print(data)
# Out:
# [{'price': '71,000', 'name': '삼성전자', 'code': '005930', 'volume': '9,745,030'}, {'price': '109,400', 'name': 'SK하이닉스', 'code': '000660', 'volume': '3,962,640'}, {'price': '587,000', 'name': 'LG에너지솔루션', 'code': '373220', 'volume': '121,718'}, {'price': '177,300', 'name': '코스모신소재', 'code': '005070', 'volume': '270,269'}, {'price': '248,000', 'name': '에코프로비엠', 'code': '247540', 'volume': '512,195'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)
df
# Out:
#      price      name    code     volume
# 0   71,000      삼성전자  005930  9,745,030
# 1  109,400    SK하이닉스  000660  3,962,640
# 2  587,000  LG에너지솔루션  373220    121,718
# 3  177,300    코스모신소재  005070    270,269
# 4  248,000    에코프로비엠  247540    512,195

# %%
df.to_excel('naver_finance.xlsx')

# %%
# 과제
# 지니 차트 200위 까지 크롤링
# 반복문을 사용하여 크롤링
# 수집한 데이터를 데이터프레임으로 저장
# 엑셀로 출력
# 과제는 github에 업로드
